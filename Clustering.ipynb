# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

# %%
# Importing Datasets
df = pd.read_csv('dataset.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# 1         4.49        76.3       1.65   4090
# 2        16.10        76.5       2.89   4460
# 3        22.40        60.1       6.16   3530
# 4         1.44        76.8       2.13  12200
# ..         ...         ...        ...    ...
# 162       2.62        63.0       3.50   2970
# 163      45.90        75.4       2.47  13500
# 164      12.10        73.1       1.95   1310
# 165      23.60        67.5       4.67   1310
# 166      14.00        52.0       5.40   1460
#
# [167 rows x 10 columns]

# %%
df_c = pd.DataFrame(df['country'])
df_c
# Out:
#                  country
# 0            Afghanistan
# 1                Albania
# 2                Algeria
# 3                 Angola
# 4    Antigua and Barbuda
# ..                   ...
# 162              Vanuatu
# 163            Venezuela
# 164              Vietnam
# 165                Yemen
# 166               Zambia
#
# [167 rows x 1 columns]

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# 50%      5.390000   73.100000    2.410000    4660.000000
# 75%     10.750000   76.800000    3.880000   14050.000000
# max    104.000000   82.800000    7.490000  105000.000000

# %% [markdown]
# <H1>Clustering with Different Features </H1>

# %% [markdown]
# <H2>1. Child_Mort

# %%
X = df.iloc[:,[9,1]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# We ignore the Elbow method result and form 3 clusters only
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Child_Mort')
plt.legend()
plt.show()

df_c['Child_Mort']=y_kmeans

# %% [markdown]
# <H2>2. Exports

# %%
X = df.iloc[:,[9,2]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Export')
plt.legend()
plt.show()

df_c['Exports']=y_kmeans

# %% [markdown]
# <H2>3. Health

# %%
X = df.iloc[:,[9,3]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Health')
plt.legend()
plt.show()

df_c['Health']=y_kmeans

# %% [markdown]
# <H2>4. Imports

# %%
X = df.iloc[:,[9,4]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Import')
plt.legend()
plt.show()

df_c['Imports']=y_kmeans

# %% [markdown]
# <H2>5. Income

# %%
X = df.iloc[:,[9,5]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Incone')
plt.legend()
plt.show()

df_c['Income']=y_kmeans

# %% [markdown]
# <H2>6. Inflation

# %%
X = df.iloc[:,[9,6]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Inflation')
plt.legend()
plt.show()

df_c['Inflation']=y_kmeans

# %% [markdown]
# <H2>7. Life Expactancy

# %%
X = df.iloc[:,[9,7]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Life Expactancy')
plt.legend()
plt.show()

df_c['Life Expactancy']=y_kmeans

# %% [markdown]
# <H2>8. Total Fertility

# %%
X = df.iloc[:,[9,8]].values
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Training the K-Means model on the dataset
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 50, c = 'r', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 50, c = 'b', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 50, c = 'g', label = 'Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 50, c = 'y', label = 'Cluster 4')
plt.title('Clusters of Countries')
plt.xlabel('GDPP')
plt.ylabel('Total Fertility')
plt.legend()
plt.show()

df_c['Fertility']=y_kmeans

# %%
print(df_c)

df_c.to_csv('Clustered_Data.csv')
# Out:
# country  Child_Mort  Exports  Health  Imports  Income  \
# 0            Afghanistan           0        0       0        0       0
# 1                Albania           0        0       0        0       0
# 2                Algeria           0        0       0        0       0
# 3                 Angola           0        0       0        0       0
# 4    Antigua and Barbuda           3        3       3        3       3
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu           0        0       0        0       0
# 163            Venezuela           3        3       3        3       3
# 164              Vietnam           0        0       0        0       0
# 165                Yemen           0        0       0        0       0
# 166               Zambia           0        0       0        0       0
#
#      Inflation  Life Expactancy  Fertility
# 0            0                0          0
# 1            0                0          0
# 2            0                0          0
# 3            0                0          0
# 4            3                3          3
# ..         ...              ...        ...
# 162          0                0          0
# 163          3                3          3
# 164          0                0          0
# 165          0                0          0
# 166          0                0          0
#
# [167 rows x 9 columns]

# %% [markdown]
# From above cluster plots we can conclude that the red clusters(no: 0) need urgent help followed by yellow cluster(no: 3) and green cluster(no: 2) don't need help at all.
