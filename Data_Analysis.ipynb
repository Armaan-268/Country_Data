# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.style.use('ggplot')

# %%
# Importing Datasets
df = pd.read_csv('dataset.csv')
df
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %% [markdown]
# <H1>Plots With Different Features </H1>

# %% [markdown]
# <H2>1. Child_Mort

# %%
x = df.iloc[:,9].values
y = df.iloc[:,1].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Child_Mort')
plt.show()

# %% [markdown]
# <H2>2. Exports

# %%
x = df.iloc[:,9].values
y = df.iloc[:,2].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Exports (% of GDP)')
plt.show()

# %% [markdown]
# <H2>3. Health

# %%
x = df.iloc[:,9].values
y = df.iloc[:,3].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Health (% of GDP)')
plt.show()

# %% [markdown]
# <H2>4. Imports

# %%
x = df.iloc[:,9].values
y = df.iloc[:,4].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Imports (% of GDP)')
plt.show()

# %% [markdown]
# <H2>5. Income

# %%
x = df.iloc[:,9].values
y = df.iloc[:,5].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Income (per person) ')
plt.show()

# %% [markdown]
# <H2>6. Inflation

# %%
x = df.iloc[:,9].values
y = df.iloc[:,6].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Inflation (Growth Rate)')
plt.show()

# %% [markdown]
# <H2>7. Life Expactancy

# %%
x = df.iloc[:,9].values
y = df.iloc[:,7].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Life Expactancy')
plt.show()

# %% [markdown]
# <H2>8. Total Fertility

# %%
x = df.iloc[:,9].values
y = df.iloc[:,8].values
plt.scatter(x,y)
plt.xlabel('GDPP')
plt.ylabel('Total Fertility')
plt.show()

# %% [markdown]
# <H2>9. GDPP

# %%
x = df.iloc[:,0].values
y = df.iloc[:,9].values
plt.scatter(x,y)
plt.xlabel('Countries')
plt.ylabel('GDPP')
plt.show()

# %% [markdown]
# By analyzing above Graphs we can see the correlation of different variables with "GDPP".Through this, we cannot draw any conclusions about which countries need help the most.
